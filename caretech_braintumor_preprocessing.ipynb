# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-mri-images-for-brain-tumor-detection' dataset.
# Path to dataset files: /kaggle/input/brain-mri-images-for-brain-tumor-detection

# %%
from pathlib import Path
import shutil

dataset_dir = Path("/kaggle/input/brain-mri-images-for-brain-tumor-detection")

new_dir = Path("/kaggle/preprocess/brain-mri-dataset")

shutil.copytree(dataset_dir, new_dir)
# Out:
# PosixPath('/kaggle/preprocess/brain-mri-dataset')

# %%
# Renamed File Extensions
yes_dir = new_dir / 'yes'
no_dir = new_dir / 'no'
total_dir = new_dir / 'brain_tumor_dataset'

extensions = ["*.jpg", "*.JPG", "*.jpeg"]

for ext in extensions:
  for path in new_dir.rglob(f'{ext}'):
    new_path = path.with_suffix('.jpg')

    path.rename(new_path)

# %%
# Exploratory Data Analysis

import os
from PIL import Image, ImageMath
import pandas as pd
import cv2
import numpy as np

img_data = []

# let yes = 1
# let no = 0

yes_files = [f for f in os.listdir(yes_dir)]
no_files = [f for f in os.listdir(no_dir)]

for f in yes_files:
  img = Image.open(os.path.join(yes_dir, f))
  img_arr = np.array(img)
  img_data.append({
      "Image": img_arr,
      "Label": 1
  })


for f in no_files:
  img = Image.open(os.path.join(no_dir, f))
  img_arr = np.array(img)
  img_data.append({
      "Image": img_arr,
      "Label": 0
  })

df = pd.DataFrame(img_data)

df.isnull().sum()
df['Label'].value_counts(normalize=True)
# there is a class imbalance, with more yes than no
# Out:
# Label
# 1    0.612648
# 0    0.387352
# Name: proportion, dtype: float64

# %%
# preprocessing: resize, normalize, apply blur
# greyscale, 224 x 224

def preprocess(image: np.ndarray) -> np.ndarray[np.float32]:
    # resize 224 x 224
    resized = cv2.resize(image, (224, 224))
    # normalize 0 - 1
    normalized = resized.astype(np.float32) / 255.0
    # noise reduction
    blurred = cv2.GaussianBlur(normalized, (3, 3), 0)

    return blurred

# preprocessing: resize, normalize, apply blur
# greyscale, 224 x 224

# before training, we'd iterate through the df and preprocess

cv2.destroyAllWindows() # in case we called it
# Out:
# Preprocessed image at /kaggle/processed/yes/Y96.jpg
# Preprocessed image at /kaggle/processed/yes/Y56.jpg
# Preprocessed image at /kaggle/processed/yes/Y251.jpg
# Preprocessed image at /kaggle/processed/yes/Y32.jpg
# Preprocessed image at /kaggle/processed/yes/Y163.jpg
# Preprocessed image at /kaggle/processed/yes/Y254.jpg
# Preprocessed image at /kaggle/processed/yes/Y243.jpg
# Preprocessed image at /kaggle/processed/yes/Y19.jpg
# Preprocessed image at /kaggle/processed/yes/Y61.jpg
# Preprocessed image at /kaggle/processed/yes/Y250.jpg
# Preprocessed image at /kaggle/processed/yes/Y17.jpg
# Preprocessed image at /kaggle/processed/yes/Y120.jpg
# Preprocessed image at /kaggle/processed/yes/Y159.jpg
# Preprocessed image at /kaggle/processed/yes/Y42.jpg
# Preprocessed image at /kaggle/processed/yes/Y4.jpg
# Preprocessed image at /kaggle/processed/yes/Y50.jpg
# Preprocessed image at /kaggle/processed/yes/Y77.jpg
# Preprocessed image at /kaggle/processed/yes/Y248.jpg
# Preprocessed image at /kaggle/processed/yes/Y3.jpg
# Preprocessed image at /kaggle/processed/yes/Y245.jpg
# Preprocessed image at /kaggle/processed/yes/Y112.jpg
# Preprocessed image at /kaggle/processed/yes/Y114.jpg
# Preprocessed image at /kaggle/processed/yes/Y188.jpg
# Preprocessed image at /kaggle/processed/yes/Y81.jpg
# Preprocessed image at /kaggle/processed/yes/Y21.jpg
# Preprocessed image at /kaggle/processed/yes/Y95.jpg
# Preprocessed image at /kaggle/processed/yes/Y54.jpg
# Preprocessed image at /kaggle/processed/yes/Y90.jpg
# Preprocessed image at /kaggle/processed/yes/Y181.jpg
# Preprocessed image at /kaggle/processed/yes/Y12.jpg
# Preprocessed image at /kaggle/processed/yes/Y51.jpg
# Preprocessed image at /kaggle/processed/yes/Y58.jpg
# Preprocessed image at /kaggle/processed/yes/Y155.jpg
# Preprocessed image at /kaggle/processed/yes/Y59.jpg
# Preprocessed image at /kaggle/processed/yes/Y249.jpg
# Preprocessed image at /kaggle/processed/yes/Y242.jpg
# Preprocessed image at /kaggle/processed/yes/Y79.jpg
# Preprocessed image at /kaggle/processed/yes/Y30.jpg
# Preprocessed image at /kaggle/processed/yes/Y154.jpg
# Preprocessed image at /kaggle/processed/yes/Y153.jpg
# Preprocessed image at /kaggle/processed/yes/Y247.jpg
# Preprocessed image at /kaggle/processed/yes/Y14.jpg
# Preprocessed image at /kaggle/processed/yes/Y106.jpg
# Preprocessed image at /kaggle/processed/yes/Y100.jpg
# Preprocessed image at /kaggle/processed/yes/Y34.jpg
# Preprocessed image at /kaggle/processed/yes/Y26.jpg
# Preprocessed image at /kaggle/processed/yes/Y24.jpg
# Preprocessed image at /kaggle/processed/yes/Y16.jpg
# Preprocessed image at /kaggle/processed/yes/Y27.jpg
# Preprocessed image at /kaggle/processed/yes/Y244.jpg
# Preprocessed image at /kaggle/processed/yes/Y98.jpg
# Preprocessed image at /kaggle/processed/yes/Y195.jpg
# Preprocessed image at /kaggle/processed/yes/Y183.jpg
# Preprocessed image at /kaggle/processed/yes/Y1.jpg
# Preprocessed image at /kaggle/processed/yes/Y76.jpg
# Preprocessed image at /kaggle/processed/yes/Y65.jpg
# Preprocessed image at /kaggle/processed/yes/Y99.jpg
# Preprocessed image at /kaggle/processed/yes/Y168.jpg
# Preprocessed image at /kaggle/processed/yes/Y182.jpg
# Preprocessed image at /kaggle/processed/yes/Y165.jpg
# Preprocessed image at /kaggle/processed/yes/Y62.jpg
# Preprocessed image at /kaggle/processed/yes/Y253.jpg
# Preprocessed image at /kaggle/processed/yes/Y166.jpg
# Preprocessed image at /kaggle/processed/yes/Y108.jpg
# Preprocessed image at /kaggle/processed/yes/Y66.jpg
# Preprocessed image at /kaggle/processed/yes/Y89.jpg
# Preprocessed image at /kaggle/processed/yes/Y146.jpg
# Preprocessed image at /kaggle/processed/yes/Y107.jpg
# Preprocessed image at /kaggle/processed/yes/Y169.jpg
# Preprocessed image at /kaggle/processed/yes/Y170.jpg
# Preprocessed image at /kaggle/processed/yes/Y70.jpg
# Preprocessed image at /kaggle/processed/yes/Y2.jpg
# Preprocessed image at /kaggle/processed/yes/Y25.jpg
# Preprocessed image at /kaggle/processed/yes/Y252.jpg
# Preprocessed image at /kaggle/processed/yes/Y49.jpg
# Preprocessed image at /kaggle/processed/yes/Y39.jpg
# Preprocessed image at /kaggle/processed/yes/Y37.jpg
# Preprocessed image at /kaggle/processed/yes/Y187.jpg
# Preprocessed image at /kaggle/processed/yes/Y101.jpg
# Preprocessed image at /kaggle/processed/yes/Y256.jpg
# Preprocessed image at /kaggle/processed/yes/Y15.jpg
# Preprocessed image at /kaggle/processed/yes/Y71.jpg
# Preprocessed image at /kaggle/processed/yes/Y38.jpg
# Preprocessed image at /kaggle/processed/yes/Y69.jpg
# Preprocessed image at /kaggle/processed/yes/Y55.jpg
# Preprocessed image at /kaggle/processed/yes/Y117.jpg
# Preprocessed image at /kaggle/processed/yes/Y109.jpg
# Preprocessed image at /kaggle/processed/yes/Y148.jpg
# Preprocessed image at /kaggle/processed/yes/Y103.jpg
# Preprocessed image at /kaggle/processed/yes/Y246.jpg
# Preprocessed image at /kaggle/processed/yes/Y18.jpg
# Preprocessed image at /kaggle/processed/yes/Y10.jpg
# Preprocessed image at /kaggle/processed/yes/Y53.jpg
# Preprocessed image at /kaggle/processed/yes/Y82.jpg
# Preprocessed image at /kaggle/processed/yes/Y33.jpg
# Preprocessed image at /kaggle/processed/yes/Y92.jpg
# Preprocessed image at /kaggle/processed/yes/Y8.jpg
# Preprocessed image at /kaggle/processed/yes/Y116.jpg
# Preprocessed image at /kaggle/processed/yes/Y20.jpg
# Preprocessed image at /kaggle/processed/yes/Y22.jpg
# Preprocessed image at /kaggle/processed/yes/Y113.jpg
# Preprocessed image at /kaggle/processed/yes/Y11.jpg
# Preprocessed image at /kaggle/processed/yes/Y78.jpg
# Preprocessed image at /kaggle/processed/yes/Y52.jpg
# Preprocessed image at /kaggle/processed/yes/Y40.jpg
# Preprocessed image at /kaggle/processed/yes/Y31.jpg
# Preprocessed image at /kaggle/processed/yes/Y13.jpg
# Preprocessed image at /kaggle/processed/yes/Y36.jpg
# Preprocessed image at /kaggle/processed/yes/Y91.jpg
# Preprocessed image at /kaggle/processed/yes/Y180.jpg
# Preprocessed image at /kaggle/processed/yes/Y156.jpg
# Preprocessed image at /kaggle/processed/yes/Y86.jpg
# Preprocessed image at /kaggle/processed/yes/Y185.jpg
# Preprocessed image at /kaggle/processed/yes/Y29.jpg
# Preprocessed image at /kaggle/processed/yes/Y73.jpg
# Preprocessed image at /kaggle/processed/yes/Y115.jpg
# Preprocessed image at /kaggle/processed/yes/Y28.jpg
# Preprocessed image at /kaggle/processed/yes/Y186.jpg
# Preprocessed image at /kaggle/processed/yes/Y35.jpg
# Preprocessed image at /kaggle/processed/yes/Y44.jpg
# Preprocessed image at /kaggle/processed/yes/Y47.jpg
# Preprocessed image at /kaggle/processed/yes/Y161.jpg
# Preprocessed image at /kaggle/processed/yes/Y41.jpg
# Preprocessed image at /kaggle/processed/yes/Y97.jpg
# Preprocessed image at /kaggle/processed/yes/Y105.jpg
# Preprocessed image at /kaggle/processed/yes/Y193.jpg
# Preprocessed image at /kaggle/processed/yes/Y255.jpg
# Preprocessed image at /kaggle/processed/yes/Y6.jpg
# Preprocessed image at /kaggle/processed/yes/Y160.jpg
# Preprocessed image at /kaggle/processed/yes/Y257.jpg
# Preprocessed image at /kaggle/processed/yes/Y7.jpg
# Preprocessed image at /kaggle/processed/yes/Y259.jpg
# Preprocessed image at /kaggle/processed/yes/Y184.jpg
# Preprocessed image at /kaggle/processed/yes/Y258.jpg
# Preprocessed image at /kaggle/processed/yes/Y45.jpg
# Preprocessed image at /kaggle/processed/yes/Y162.jpg
# Preprocessed image at /kaggle/processed/yes/Y85.jpg
# Preprocessed image at /kaggle/processed/yes/Y157.jpg
# Preprocessed image at /kaggle/processed/yes/Y111.jpg
# Preprocessed image at /kaggle/processed/yes/Y74.jpg
# Preprocessed image at /kaggle/processed/yes/Y104.jpg
# Preprocessed image at /kaggle/processed/yes/Y60.jpg
# Preprocessed image at /kaggle/processed/yes/Y9.jpg
# Preprocessed image at /kaggle/processed/yes/Y164.jpg
# Preprocessed image at /kaggle/processed/yes/Y158.jpg
# Preprocessed image at /kaggle/processed/yes/Y23.jpg
# Preprocessed image at /kaggle/processed/yes/Y67.jpg
# Preprocessed image at /kaggle/processed/yes/Y46.jpg
# Preprocessed image at /kaggle/processed/yes/Y192.jpg
# Preprocessed image at /kaggle/processed/yes/Y194.jpg
# Preprocessed image at /kaggle/processed/yes/Y102.jpg
# Preprocessed image at /kaggle/processed/yes/Y147.jpg
# Preprocessed image at /kaggle/processed/yes/Y75.jpg
# Preprocessed image at /kaggle/processed/yes/Y167.jpg
# Preprocessed image at /kaggle/processed/no/42 no.jpg
# Preprocessed image at /kaggle/processed/no/No11.jpg
# Preprocessed image at /kaggle/processed/no/10 no.jpg
# Preprocessed image at /kaggle/processed/no/25 no.jpg
# Preprocessed image at /kaggle/processed/no/no 92.jpg
# Preprocessed image at /kaggle/processed/no/no 96.jpg
# Preprocessed image at /kaggle/processed/no/43 no.jpg
# Preprocessed image at /kaggle/processed/no/no 99.jpg
# Preprocessed image at /kaggle/processed/no/29 no.jpg
# Preprocessed image at /kaggle/processed/no/No20.jpg
# Preprocessed image at /kaggle/processed/no/46 no.jpg
# Preprocessed image at /kaggle/processed/no/23 no.jpg
# Preprocessed image at /kaggle/processed/no/no 4.jpg
# Preprocessed image at /kaggle/processed/no/no 90.jpg
# Preprocessed image at /kaggle/processed/no/N15.jpg
# Preprocessed image at /kaggle/processed/no/no 7.jpg
# Preprocessed image at /kaggle/processed/no/21 no.jpg
# Preprocessed image at /kaggle/processed/no/no 8.jpg
# Preprocessed image at /kaggle/processed/no/no 5.jpg
# Preprocessed image at /kaggle/processed/no/27 no.jpg
# Preprocessed image at /kaggle/processed/no/No22.jpg
# Preprocessed image at /kaggle/processed/no/no.jpg
# Preprocessed image at /kaggle/processed/no/39 no.jpg
# Preprocessed image at /kaggle/processed/no/no 89.jpg
# Preprocessed image at /kaggle/processed/no/no 95.jpg
# Preprocessed image at /kaggle/processed/no/No12.jpg
# Preprocessed image at /kaggle/processed/no/49 no.jpg
# Preprocessed image at /kaggle/processed/no/N6.jpg
# Preprocessed image at /kaggle/processed/no/N2.jpg
# Preprocessed image at /kaggle/processed/no/24 no.jpg
# Preprocessed image at /kaggle/processed/no/22 no.jpg
# Preprocessed image at /kaggle/processed/no/33 no.jpg
# Preprocessed image at /kaggle/processed/no/N5.jpg
# Preprocessed image at /kaggle/processed/no/32 no.jpg
# Preprocessed image at /kaggle/processed/no/No17.jpg
# Preprocessed image at /kaggle/processed/no/8 no.jpg
# Preprocessed image at /kaggle/processed/no/50 no.jpg
# Preprocessed image at /kaggle/processed/no/14 no.jpg
# Preprocessed image at /kaggle/processed/no/41 no.jpg
# Preprocessed image at /kaggle/processed/no/40 no.jpg
# Preprocessed image at /kaggle/processed/no/9 no.jpg
# Preprocessed image at /kaggle/processed/no/15 no.jpg
# Preprocessed image at /kaggle/processed/no/no 6.jpg
# Preprocessed image at /kaggle/processed/no/37 no.jpg
# Preprocessed image at /kaggle/processed/no/47 no.jpg
# Preprocessed image at /kaggle/processed/no/N3.jpg
# Preprocessed image at /kaggle/processed/no/No16.jpg
# Preprocessed image at /kaggle/processed/no/26 no.jpg
# Preprocessed image at /kaggle/processed/no/N21.jpg
# Preprocessed image at /kaggle/processed/no/3 no.jpg
# Preprocessed image at /kaggle/processed/no/no 100.jpg
# Preprocessed image at /kaggle/processed/no/N22.jpg
# Preprocessed image at /kaggle/processed/no/35 no.jpg
# Preprocessed image at /kaggle/processed/no/6 no.jpg
# Preprocessed image at /kaggle/processed/no/no 98.jpg
# Preprocessed image at /kaggle/processed/no/no 923.jpg
# Preprocessed image at /kaggle/processed/no/45 no.jpg
# Preprocessed image at /kaggle/processed/no/12 no.jpg
# Preprocessed image at /kaggle/processed/no/No14.jpg
# Preprocessed image at /kaggle/processed/no/48 no.jpg
# Preprocessed image at /kaggle/processed/no/No15.jpg
# Preprocessed image at /kaggle/processed/no/N16.jpg
# Preprocessed image at /kaggle/processed/no/4 no.jpg
# Preprocessed image at /kaggle/processed/no/28 no.jpg
# Preprocessed image at /kaggle/processed/no/no 10.jpg
# Preprocessed image at /kaggle/processed/no/No13.jpg
# Preprocessed image at /kaggle/processed/no/No21.jpg
# Preprocessed image at /kaggle/processed/no/30 no.jpg
# Preprocessed image at /kaggle/processed/no/7 no.jpg
# Preprocessed image at /kaggle/processed/no/17 no.jpg
# Preprocessed image at /kaggle/processed/no/no 94.jpg
# Preprocessed image at /kaggle/processed/no/N26.jpg
# Preprocessed image at /kaggle/processed/no/36 no.jpg
# Preprocessed image at /kaggle/processed/no/38 no.jpg
# Preprocessed image at /kaggle/processed/no/11 no.jpg
# Preprocessed image at /kaggle/processed/no/no 2.jpg
# Preprocessed image at /kaggle/processed/no/20 no.jpg
# Preprocessed image at /kaggle/processed/no/13 no.jpg
# Preprocessed image at /kaggle/processed/no/no 97.jpg
# Preprocessed image at /kaggle/processed/no/18 no.jpg
# Preprocessed image at /kaggle/processed/no/31 no.jpg
# Preprocessed image at /kaggle/processed/no/19 no.jpg
# Preprocessed image at /kaggle/processed/no/N20.jpg
# Preprocessed image at /kaggle/processed/no/N17.jpg
# Preprocessed image at /kaggle/processed/no/N1.jpg
# Preprocessed image at /kaggle/processed/no/No18.jpg
# Preprocessed image at /kaggle/processed/no/44no.jpg
# Preprocessed image at /kaggle/processed/no/5 no.jpg
# Preprocessed image at /kaggle/processed/no/no 91.jpg
# Preprocessed image at /kaggle/processed/no/1 no.jpg
# Preprocessed image at /kaggle/processed/no/no 3.jpg
# Preprocessed image at /kaggle/processed/no/No19.jpg
# Preprocessed image at /kaggle/processed/no/N19.jpg
# Preprocessed image at /kaggle/processed/no/N11.jpg
# Preprocessed image at /kaggle/processed/no/2 no.jpg
# Preprocessed image at /kaggle/processed/no/no 1.jpg
# Preprocessed image at /kaggle/processed/no/34 no.jpg
